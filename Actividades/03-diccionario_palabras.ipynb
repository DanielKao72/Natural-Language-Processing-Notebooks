# %% [markdown]
# ### 1. Importamos la librería *nltk*

# %%
import nltk

# %% [markdown]
# ### 2. Descargamos *wordnet* desde *nltk*

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\danik\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# ### 3. Importamos *wordnet*

# %%
from nltk.corpus import wordnet as wn

# %% [markdown]
# ### 4. Abrimos el archivo txt que contiene las palabras a buscar en *wordnet*

# %%
with open("../Textos de Prueba/palabras.txt", "r", encoding="utf-8") as f:
    palabras = [line.strip() for line in f if line.strip()]
    print(palabras)
# Out:
# ['area', 'book', 'business', 'case', 'child', 'company', 'country', 'day', 'eye', 'fact', 'family', 'government', 'group', 'hand', 'home', 'job', 'life', 'lot', 'man', 'money', 'month', 'mother', 'night', 'number', 'part', 'people', 'place', 'point', 'problem', 'program', 'question', 'right', 'room', 'school', 'state', 'story', 'student', 'study', 'system', 'thing', 'time', 'water', 'way', 'week', 'woman', 'word', 'work', 'world', 'year']

# %% [markdown]
# ### 5. Creamos un diccionario con el contenido del archivo a generar.
# En el diccionario se encuentra como llave la palabra y su valor es la lista de definiciones de dicha palabra. Todo obtenido de *wordnet*

# %%
diccionario = {}

for palabra in palabras:
    synsets = wn.synsets(palabra)
    definiciones = [syn.definition() for syn in synsets]
    diccionario[palabra] = definiciones

# %% [markdown]
# ### 6.1. Imprimimos en consola el contenido del diccionario

# %%
for palabra, defs in diccionario.items():
    print(palabra)
    for i, d in enumerate(defs, 1):
        print(f"   Def {i}: {d}")
    print()
# Out:
# area
#    Def 1: a particular geographical region of indefinite boundary (usually serving some special purpose or distinguished by its people or culture or geography)
#    Def 2: a subject of study
#    Def 3: a part of an animal that has a special function or is supplied by a given artery or nerve
#    Def 4: a particular environment or walk of life
#    Def 5: a part of a structure having some specific characteristic or function
#    Def 6: the extent of a 2-dimensional surface enclosed within a boundary
#
# book
#    Def 1: a written work or composition that has been published (printed on pages bound together)
#    Def 2: physical objects consisting of a number of pages bound together
#    Def 3: a compilation of the known facts regarding something or someone
#    Def 4: a written version of a play or other dramatic composition; used in preparing for a performance
#    Def 5: a record in which commercial accounts are recorded
# ...

# %% [markdown]
# ### 6.2. Creamos el archivo Diccionario Wordnet.txt con el contenido del diccionario generado

# %%
# Guardar diccionario en un archivo de texto
with open("Diccionario Wordnet.txt", "w", encoding="utf-8") as f:
    for palabra, defs in diccionario.items():
        f.write(palabra + "\n")  # Escribe la palabra
        for i, d in enumerate(defs, 1):
            f.write(f"   Def {i}: {d}\n")  # Escribe cada definición
        f.write("\n")  # Línea en blanco entre palabras

print("Archivo 'diccionario.txt' generado ✅")
# Out:
# Archivo 'diccionario.txt' generado ✅
